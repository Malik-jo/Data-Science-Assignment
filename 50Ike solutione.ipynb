# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize' : [8,8]},font_scale=1.3)

# %%
df=pd.read_csv('50lke.csv')
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.describe()
# Out:
#        Unnamed: 0  National Income     Growth    Per person
# count    50.00000        50.000000  50.000000     50.000000
# mean     24.50000      1646.348200   3.320400  27696.000000
# std      14.57738      3448.554429   2.053468  25094.131496
# min       0.00000       231.570000  -0.740000   1615.000000
# 25%      12.25000       353.440000   1.795000   6402.000000
# 50%      24.50000       522.985000   2.880000  14565.500000
# 75%      36.75000      1504.895000   4.287500  48738.250000
# max      49.00000     20412.870000   7.810000  86835.000000

# %%
sns.distplot(df['National Income'],kde=False , color='k')

# %%
sns.kdeplot(df['Growth'],shade=True , color='k')

# %%
sns.kdeplot(df['Per person'],shade=True , color='r')

# %%
sns.jointplot(x='Growth' , y='National Income',data=df,kind='scatter' ,height=7 , ratio=10)

# %%
sns.jointplot(x='Growth' , y='National Income',data=df,kind='kde' ,height=7 , ratio=10)

# %%
sns.jointplot(x='Growth' , y='National Income',data=df,kind='hex' ,height=7 , ratio=10)

# %%
sns.pairplot(df)

# %%
sns.boxplot(x='Continent' ,y='Per person' , data=df ,  palette='viridis')

# %%
sns.violinplot(x='Continent' , y='Per person' , data=df)

# %%
sns.boxplot(x="Continent", y="National Income", data=df, palette='viridis')

# %%
sns.violinplot(x="Continent", y="Growth", data=df, palette='viridis')

# %%
sns.barplot(x='Continent' , y='Growth' , data=df)

# %%
sns.barplot(x='Continent' , y='Per person',data = df)

# %%
sns.countplot(x='Continent' , data=df)

# %%
sns.stripplot(x='Continent' , y='Per person', data =df)

# %%
sns.swarmplot(x='Continent' , y='Per person',data=df)

# %%
sns.lmplot(x='Per person', y='National Income', data=df, height=5, aspect=1)
